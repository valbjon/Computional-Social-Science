# %%
import pandas as pd 
import tensorflow
from bs4 import BeautifulSoup
import re
import timeit
import requests
import wikipedia

# %%
def crawl_year(year, yearContent, df):
    """ Crawl the different years of the wikipedia's archieved deletion discussions page and store the content
        in a Data Frame. 

        Args: 
            year: the year in which the archived articles were flagged for deletion
            yearContent: the html content containing the year (a h2 tag)
            df: the data frame where the data are stored in the format year | month | title | Id | Gender

        Returns:
            a data frame
    """
    for monthContent in yearContent.find_next_siblings(limit=24):
        if monthContent.name == "h2":
            # Crawl only this year. If the year doesn't yet have 12 months(e.g. 2019), don't go for more.
            break
        elif monthContent.name == "h3":
            month = monthContent.get_text().split(str(year)+" ")[1].split("[")[0]
            print("Month",month)
        elif monthContent.name == "ul":
            # Go through the list of days
            for dayRelative in monthContent.find_all("a"):
                print(dayRelative['href'])
                dayPageLink = "https://en.wikipedia.org/"+dayRelative['href']
                try :
                    dayPage = requests.get(dayPageLink)
                except requests.exceptions.RequestException as e:
                    continue
                soupPage = BeautifulSoup(dayPage.content, "html.parser")

                if dayPage.status_code == 200:
                    
                    # Get the number of articles in a particular day
                    articlesLength = float(soupPage.find_all("ul")[2].find_all("li")[-1].get_text().split(" ")[0])
                    numberDec = round(articlesLength % 1 * 10, 2)
                    if int(numberDec) != numberDec:
                        numberDec *= 10
                    articlesLength = int(articlesLength) + numberDec
                    print("Articles to be crawled in this page: ",articlesLength)

                    # Every article is located in an <h3> tag
                    for article in soupPage.find_all("h3", limit = articlesLength):
                        try:
                            # Don't read deleted articles
                            if article.find("a")['title'].find("(page does") == -1:
                                articleTitle = article.get_text().split("[")[0]
                                pageLink = "https://en.wikipedia.org"+article.find("a")['href']
                                df = crawl_article(year, month, articleTitle, pageLink, df)
                        except Exception as e:
                            continue
    return df

# %%
def crawl_article(year, month, title, pageLink, df):
    """ Crawl the content of the corresponding dbpedia page of a wikipedia article in order to get its id and gender.
        Store an entry in the dataframe.

        Args:
            year: the year in which the current article was flagged for deletion
            month: the month in which the current article was flagged for deletion
            articleTitle: the title of the article flagged for deletion
            pageLink: the wikipedia link of the article
            df: the data frame where the data are stored in the format year | month | title | Id | gender

        Returns:
            A data frame
    """
    url = "http://dbpedia.org/page/"+pageLink.split("/wiki/")[1]
    try :
        dbpediaPage = requests.get(url)
    except requests.exceptions.RequestException as e:
        return df
    soup = BeautifulSoup(dbpediaPage.content, "html.parser")
    wikiIdTag = soup.find("span", {"property":"dbo:wikiPageID"})
    genderTag = soup.find("span", {"property":"foaf:gender"})
    if genderTag == None:
        # Not a person
        return df
    dic = {"Year":year, "Month":month, "Tile":title, "Id": wikiIdTag.contents[0]
           , "Gender":genderTag.contents[0]}
    if df.empty:
        df = pd.DataFrame(data=dic, index=[0])
    else:
        df_temp = pd.DataFrame(data=dic, index=[0])
        df = pd.concat([df, df_temp])
    return df

# %%
startTime = timeit.default_timer()

seedURL = "https://en.wikipedia.org/wiki/Wikipedia:Archived_deletion_discussions#Deletion_discussions/"
archivePage = requests.get(seedURL)
soup = BeautifulSoup(archivePage.content, "html.parser")

# Get the year
years = []
yearContents = []
for yearContent in soup.find_all("h2", limit=10):
    year = yearContent.get_text().split("[")[0]
    if year == "Contents":
        continue
    years.append(year)
    yearContents.append(yearContent)

# print(yearContents[5].find_next_sibling)
df = pd.DataFrame()
df = crawl_year(years[5], yearContents[5], df)

elapsedTime = timeit.default_timer() - startTime
print("Crawl time ", elapsedTime)
# Out:
# Month December
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_December_31
# Articles to be crawled in this page:  39.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_December_30
# Articles to be crawled in this page:  85.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_December_29
# Articles to be crawled in this page:  37.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_December_28
# Articles to be crawled in this page:  41.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_December_27
# Articles to be crawled in this page:  65.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_December_26
# Articles to be crawled in this page:  49.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_December_25
# Articles to be crawled in this page:  59.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_December_24
# Articles to be crawled in this page:  34.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_December_23
# Articles to be crawled in this page:  96.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_December_22
# Articles to be crawled in this page:  56.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_December_21
# Articles to be crawled in this page:  36.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_December_20
# Articles to be crawled in this page:  44.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_December_19
# Articles to be crawled in this page:  46.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_December_18
# Articles to be crawled in this page:  28.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_December_17
# Articles to be crawled in this page:  42.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_December_16
# Articles to be crawled in this page:  72.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_December_15
# Articles to be crawled in this page:  47.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_December_14
# Articles to be crawled in this page:  65.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_December_13
# Articles to be crawled in this page:  49.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_December_12
# Articles to be crawled in this page:  35.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_December_11
# Articles to be crawled in this page:  44.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_December_10
# Articles to be crawled in this page:  37.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_December_9
# Articles to be crawled in this page:  57.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_December_8
# Articles to be crawled in this page:  40.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_December_7
# Articles to be crawled in this page:  26.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_December_6
# Articles to be crawled in this page:  8.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_December_5
# Articles to be crawled in this page:  42.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_December_4
# Articles to be crawled in this page:  34.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_December_3
# Articles to be crawled in this page:  67.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_December_2
# Articles to be crawled in this page:  60.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_December_1
# Articles to be crawled in this page:  57.0
# Month November
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_November_30
# Articles to be crawled in this page:  49.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_November_29
# Articles to be crawled in this page:  53.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_November_28
# Articles to be crawled in this page:  34.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_November_27
# Articles to be crawled in this page:  43.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_November_26
# Articles to be crawled in this page:  44.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_November_25
# Articles to be crawled in this page:  63.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_November_24
# Articles to be crawled in this page:  24.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_November_23
# Articles to be crawled in this page:  48.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_November_22
# Articles to be crawled in this page:  63.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_November_21
# Articles to be crawled in this page:  40.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_November_20
# Articles to be crawled in this page:  32.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_November_19
# Articles to be crawled in this page:  44.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_November_18
# Articles to be crawled in this page:  69.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_November_17
# Articles to be crawled in this page:  40.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_November_16
# Articles to be crawled in this page:  63.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_November_15
# Articles to be crawled in this page:  61.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_November_14
# Articles to be crawled in this page:  40.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_November_13
# Articles to be crawled in this page:  78.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_November_12
# Articles to be crawled in this page:  58.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_November_11
# Articles to be crawled in this page:  52.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_November_10
# Articles to be crawled in this page:  57.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_November_9
# Articles to be crawled in this page:  58.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_November_8
# Articles to be crawled in this page:  32.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_November_7
# Articles to be crawled in this page:  69.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_November_6
# Articles to be crawled in this page:  49.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_November_5
# Articles to be crawled in this page:  53.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_November_4
# Articles to be crawled in this page:  50.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_November_3
# Articles to be crawled in this page:  70.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_November_2
# Articles to be crawled in this page:  49.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_November_1
# Articles to be crawled in this page:  38.0
# Month October
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_October_31
# Articles to be crawled in this page:  51.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_October_30
# Articles to be crawled in this page:  51.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_October_29
# Articles to be crawled in this page:  54.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_October_28
# Articles to be crawled in this page:  59.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_October_27
# Articles to be crawled in this page:  46.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_October_26
# Articles to be crawled in this page:  42.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_October_25
# Articles to be crawled in this page:  38.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_October_24
# Articles to be crawled in this page:  37.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_October_23
# Articles to be crawled in this page:  58.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_October_22
# Articles to be crawled in this page:  40.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_October_21
# Articles to be crawled in this page:  66.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_October_20
# Articles to be crawled in this page:  33.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_October_19
# Articles to be crawled in this page:  41.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_October_18
# Articles to be crawled in this page:  81.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_October_17
# Articles to be crawled in this page:  49.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_October_16
# Articles to be crawled in this page:  44.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_October_15
# Articles to be crawled in this page:  69.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_October_14
# Articles to be crawled in this page:  71.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_October_13
# Articles to be crawled in this page:  79.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_October_12
# Articles to be crawled in this page:  24.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_October_11
# Articles to be crawled in this page:  51.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_October_10
# Articles to be crawled in this page:  57.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_October_9
# Articles to be crawled in this page:  63.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_October_8
# Articles to be crawled in this page:  50.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_October_7
# Articles to be crawled in this page:  57.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_October_6
# Articles to be crawled in this page:  48.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_October_5
# Articles to be crawled in this page:  56.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_October_4
# Articles to be crawled in this page:  63.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_October_3
# Articles to be crawled in this page:  46.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_October_2
# Articles to be crawled in this page:  70.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_October_1
# Articles to be crawled in this page:  70.0
# Month September
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_September_30
# Articles to be crawled in this page:  110.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_September_29
# Articles to be crawled in this page:  45.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_September_28
# Articles to be crawled in this page:  42.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_September_27
# Articles to be crawled in this page:  44.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_September_26
# Articles to be crawled in this page:  38.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_September_25
# Articles to be crawled in this page:  53.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_September_24
# Articles to be crawled in this page:  76.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_September_23
# Articles to be crawled in this page:  90.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_September_22
# Articles to be crawled in this page:  102.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_September_21
# Articles to be crawled in this page:  107.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_September_20
# Articles to be crawled in this page:  100.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_September_19
# Articles to be crawled in this page:  74.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_September_18
# Articles to be crawled in this page:  46.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_September_17
# Articles to be crawled in this page:  62.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_September_16
# Articles to be crawled in this page:  65.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_September_15
# Articles to be crawled in this page:  87.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_September_14
# Articles to be crawled in this page:  94.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_September_13
# Articles to be crawled in this page:  117.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_September_12
# Articles to be crawled in this page:  92.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_September_11
# Articles to be crawled in this page:  64.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_September_10
# Articles to be crawled in this page:  30.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_September_9
# Articles to be crawled in this page:  76.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_September_8
# Articles to be crawled in this page:  83.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_September_7
# Articles to be crawled in this page:  51.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_September_6
# Articles to be crawled in this page:  58.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_September_5
# Articles to be crawled in this page:  53.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_September_4
# Articles to be crawled in this page:  55.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_September_3
# Articles to be crawled in this page:  82.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_September_2
# Articles to be crawled in this page:  83.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_September_1
# Articles to be crawled in this page:  55.0
# Month August
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_August_31
# Articles to be crawled in this page:  59.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_August_30
# Articles to be crawled in this page:  58.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_August_29
# Articles to be crawled in this page:  48.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_August_28
# Articles to be crawled in this page:  70.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_August_27
# Articles to be crawled in this page:  68.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_August_26
# Articles to be crawled in this page:  43.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_August_25
# Articles to be crawled in this page:  47.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_August_24
# Articles to be crawled in this page:  61.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_August_23
# Articles to be crawled in this page:  72.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_August_22
# Articles to be crawled in this page:  41.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_August_21
# Articles to be crawled in this page:  78.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_August_20
# Articles to be crawled in this page:  56.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_August_19
# Articles to be crawled in this page:  49.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_August_18
# Articles to be crawled in this page:  47.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_August_17
# Articles to be crawled in this page:  56.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_August_16
# Articles to be crawled in this page:  34.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_August_15
# Articles to be crawled in this page:  84.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_August_14
# Articles to be crawled in this page:  59.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_August_13
# Articles to be crawled in this page:  88.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_August_12
# Articles to be crawled in this page:  77.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_August_11
# Articles to be crawled in this page:  78.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_August_10
# Articles to be crawled in this page:  51.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_August_9
# Articles to be crawled in this page:  43.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_August_8
# Articles to be crawled in this page:  53.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_August_7
# Articles to be crawled in this page:  74.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_August_6
# Articles to be crawled in this page:  74.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_August_5
# Articles to be crawled in this page:  69.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_August_4
# Articles to be crawled in this page:  52.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_August_3
# Articles to be crawled in this page:  54.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_August_2
# Articles to be crawled in this page:  53.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_August_1
# Articles to be crawled in this page:  24.0
# Month July
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_July_31
# Articles to be crawled in this page:  58.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_July_30
# Articles to be crawled in this page:  55.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_July_29
# Articles to be crawled in this page:  56.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_July_28
# Articles to be crawled in this page:  68.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_July_27
# Articles to be crawled in this page:  60.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_July_26
# Articles to be crawled in this page:  61.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_July_25
# Articles to be crawled in this page:  66.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_July_24
# Articles to be crawled in this page:  59.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_July_23
# Articles to be crawled in this page:  98.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_July_22
# Articles to be crawled in this page:  52.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_July_21
# Articles to be crawled in this page:  40.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_July_20
# Articles to be crawled in this page:  78.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_July_19
# Articles to be crawled in this page:  74.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_July_18
# Articles to be crawled in this page:  51.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_July_17
# Articles to be crawled in this page:  57.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_July_16
# Articles to be crawled in this page:  67.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_July_15
# Articles to be crawled in this page:  69.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_July_14
# Articles to be crawled in this page:  53.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_July_13
# Articles to be crawled in this page:  45.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_July_12
# Articles to be crawled in this page:  49.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_July_11
# Articles to be crawled in this page:  47.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_July_10
# Articles to be crawled in this page:  62.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_July_9
# Articles to be crawled in this page:  64.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_July_8
# Articles to be crawled in this page:  74.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_July_7
# Articles to be crawled in this page:  64.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_July_6
# Articles to be crawled in this page:  81.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_July_5
# Articles to be crawled in this page:  38.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_July_4
# Articles to be crawled in this page:  78.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_July_3
# Articles to be crawled in this page:  70.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_July_2
# Articles to be crawled in this page:  52.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_July_1
# Articles to be crawled in this page:  51.0
# Month June
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_June_30
# Articles to be crawled in this page:  32.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_June_29
# Articles to be crawled in this page:  72.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_June_28
# Articles to be crawled in this page:  31.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_June_27
# Articles to be crawled in this page:  52.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_June_26
# Articles to be crawled in this page:  56.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_June_25
# Articles to be crawled in this page:  44.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_June_24
# Articles to be crawled in this page:  51.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_June_23
# Articles to be crawled in this page:  75.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_June_22
# Articles to be crawled in this page:  43.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_June_21
# Articles to be crawled in this page:  64.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_June_20
# Articles to be crawled in this page:  44.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_June_19
# Articles to be crawled in this page:  81.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_June_18
# Articles to be crawled in this page:  62.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_June_17
# Articles to be crawled in this page:  61.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_June_16
# Articles to be crawled in this page:  104.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_June_15
# Articles to be crawled in this page:  32.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_June_14
# Articles to be crawled in this page:  67.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_June_13
# Articles to be crawled in this page:  42.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_June_12
# Articles to be crawled in this page:  52.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_June_11
# Articles to be crawled in this page:  83.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_June_10
# Articles to be crawled in this page:  48.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_June_9
# Articles to be crawled in this page:  34.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_June_8
# Articles to be crawled in this page:  40.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_June_7
# Articles to be crawled in this page:  44.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_June_6
# Articles to be crawled in this page:  41.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_June_5
# Articles to be crawled in this page:  48.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_June_4
# Articles to be crawled in this page:  41.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_June_3
# Articles to be crawled in this page:  47.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_June_2
# Articles to be crawled in this page:  86.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_June_1
# Articles to be crawled in this page:  43.0
# Month May
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_May_31
# Articles to be crawled in this page:  40.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_May_30
# Articles to be crawled in this page:  65.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_May_29
# Articles to be crawled in this page:  43.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_May_28
# Articles to be crawled in this page:  76.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_May_27
# Articles to be crawled in this page:  49.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_May_26
# Articles to be crawled in this page:  67.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_May_25
# Articles to be crawled in this page:  36.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_May_24
# Articles to be crawled in this page:  43.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_May_23
# Articles to be crawled in this page:  57.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_May_22
# Articles to be crawled in this page:  34.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_May_21
# Articles to be crawled in this page:  50.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_May_20
# Articles to be crawled in this page:  45.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_May_19
# Articles to be crawled in this page:  40.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_May_18
# Articles to be crawled in this page:  57.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_May_17
# Articles to be crawled in this page:  16.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_May_16
# Articles to be crawled in this page:  31.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_May_15
# Articles to be crawled in this page:  54.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_May_14
# Articles to be crawled in this page:  43.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_May_13
# Articles to be crawled in this page:  58.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_May_12
# Articles to be crawled in this page:  93.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_May_11
# Articles to be crawled in this page:  61.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_May_10
# Articles to be crawled in this page:  58.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_May_9
# Articles to be crawled in this page:  77.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_May_8
# Articles to be crawled in this page:  83.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_May_7
# Articles to be crawled in this page:  40.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_May_6
# Articles to be crawled in this page:  45.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_May_5
# Articles to be crawled in this page:  40.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_May_4
# Articles to be crawled in this page:  59.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_May_3
# Articles to be crawled in this page:  41.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_May_2
# Articles to be crawled in this page:  51.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_May_1
# Articles to be crawled in this page:  53.0
# Month April
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_April_30
# Articles to be crawled in this page:  48.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_April_29
# Articles to be crawled in this page:  52.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_April_28
# Articles to be crawled in this page:  37.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_April_27
# Articles to be crawled in this page:  25.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_April_26
# Articles to be crawled in this page:  32.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_April_25
# Articles to be crawled in this page:  41.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_April_24
# Articles to be crawled in this page:  50.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_April_23
# Articles to be crawled in this page:  72.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_April_22
# Articles to be crawled in this page:  81.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_April_21
# Articles to be crawled in this page:  52.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_April_20
# Articles to be crawled in this page:  48.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_April_19
# Articles to be crawled in this page:  51.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_April_18
# Articles to be crawled in this page:  51.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_April_17
# Articles to be crawled in this page:  37.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_April_16
# Articles to be crawled in this page:  65.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_April_15
# Articles to be crawled in this page:  44.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_April_14
# Articles to be crawled in this page:  48.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_April_13
# Articles to be crawled in this page:  68.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_April_12
# Articles to be crawled in this page:  44.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_April_11
# Articles to be crawled in this page:  47.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_April_10
# Articles to be crawled in this page:  72.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_April_9
# Articles to be crawled in this page:  41.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_April_8
# Articles to be crawled in this page:  59.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_April_7
# Articles to be crawled in this page:  51.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_April_6
# Articles to be crawled in this page:  57.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_April_5
# Articles to be crawled in this page:  52.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_April_4
# Articles to be crawled in this page:  49.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_April_3
# Articles to be crawled in this page:  53.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_April_2
# Articles to be crawled in this page:  78.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_April_1
# Articles to be crawled in this page:  78.0
# Month March
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_March_31
# Articles to be crawled in this page:  40.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_March_30
# Articles to be crawled in this page:  54.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_March_29
# Articles to be crawled in this page:  7.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_March_28
# Articles to be crawled in this page:  52.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_March_27
# Articles to be crawled in this page:  47.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_March_26
# Articles to be crawled in this page:  41.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_March_25
# Articles to be crawled in this page:  58.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_March_24
# Articles to be crawled in this page:  93.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_March_23
# Articles to be crawled in this page:  35.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_March_22
# Articles to be crawled in this page:  67.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_March_21
# Articles to be crawled in this page:  91.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_March_20
# Articles to be crawled in this page:  46.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_March_19
# Articles to be crawled in this page:  38.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_March_18
# Articles to be crawled in this page:  56.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_March_17
# Articles to be crawled in this page:  35.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_March_16
# Articles to be crawled in this page:  35.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_March_15
# Articles to be crawled in this page:  33.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_March_14
# Articles to be crawled in this page:  52.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_March_13
# Articles to be crawled in this page:  46.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_March_12
# Articles to be crawled in this page:  66.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_March_11
# Articles to be crawled in this page:  62.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_March_10
# Articles to be crawled in this page:  34.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_March_9
# Articles to be crawled in this page:  36.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_March_8
# Articles to be crawled in this page:  64.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_March_7
# Articles to be crawled in this page:  51.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_March_6
# Articles to be crawled in this page:  33.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_March_5
# Articles to be crawled in this page:  35.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_March_4
# Articles to be crawled in this page:  62.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_March_3
# Articles to be crawled in this page:  80.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_March_2
# Articles to be crawled in this page:  55.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_March_1
# Articles to be crawled in this page:  61.0
# Month February
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_February_28
# Articles to be crawled in this page:  42.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_February_27
# Articles to be crawled in this page:  30.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_February_26
# Articles to be crawled in this page:  58.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_February_25
# Articles to be crawled in this page:  47.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_February_24
# Articles to be crawled in this page:  36.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_February_23
# Articles to be crawled in this page:  66.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_February_22
# Articles to be crawled in this page:  91.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_February_21
# Articles to be crawled in this page:  47.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_February_20
# Articles to be crawled in this page:  84.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_February_19
# Articles to be crawled in this page:  57.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_February_18
# Articles to be crawled in this page:  56.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_February_17
# Articles to be crawled in this page:  54.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_February_16
# Articles to be crawled in this page:  38.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_February_15
# Articles to be crawled in this page:  69.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_February_14
# Articles to be crawled in this page:  24.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_February_13
# Articles to be crawled in this page:  55.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_February_12
# Articles to be crawled in this page:  49.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_February_11
# Articles to be crawled in this page:  51.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_February_10
# Articles to be crawled in this page:  108.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_February_9
# Articles to be crawled in this page:  145.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_February_8
# Articles to be crawled in this page:  37.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_February_7
# Articles to be crawled in this page:  28.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_February_6
# Articles to be crawled in this page:  103.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_February_5
# Articles to be crawled in this page:  41.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_February_4
# Articles to be crawled in this page:  45.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_February_3
# Articles to be crawled in this page:  60.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_February_2
# Articles to be crawled in this page:  44.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_February_1
# Articles to be crawled in this page:  52.0
# Month January
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_January_31
# Articles to be crawled in this page:  46.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_January_30
# Articles to be crawled in this page:  57.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_January_29
# Articles to be crawled in this page:  39.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_January_28
# Articles to be crawled in this page:  57.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_January_27
# Articles to be crawled in this page:  92.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_January_26
# Articles to be crawled in this page:  83.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_January_25
# Articles to be crawled in this page:  97.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_January_24
# Articles to be crawled in this page:  54.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_January_23
# Articles to be crawled in this page:  57.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_January_22
# Articles to be crawled in this page:  38.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_January_21
# Articles to be crawled in this page:  30.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_January_20
# Articles to be crawled in this page:  51.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_January_19
# Articles to be crawled in this page:  70.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_January_18
# Articles to be crawled in this page:  47.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_January_17
# Articles to be crawled in this page:  68.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_January_16
# Articles to be crawled in this page:  73.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_January_15
# Articles to be crawled in this page:  54.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_January_14
# Articles to be crawled in this page:  119.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_January_13
# Articles to be crawled in this page:  80.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_January_12
# Articles to be crawled in this page:  117.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_January_11
# Articles to be crawled in this page:  71.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_January_10
# Articles to be crawled in this page:  38.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_January_9
# Articles to be crawled in this page:  44.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_January_8
# Articles to be crawled in this page:  74.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_January_7
# Articles to be crawled in this page:  50.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_January_6
# Articles to be crawled in this page:  71.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_January_5
# Articles to be crawled in this page:  55.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_January_4
# Articles to be crawled in this page:  56.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_January_3
# Articles to be crawled in this page:  122.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_January_2
# Articles to be crawled in this page:  74.0
# /wiki/Wikipedia:Articles_for_deletion/Log/2014_January_1
# Articles to be crawled in this page:  59.0
# Crawl time  12126.415200056694

# %%
df
# Out:
#     Year     Month                              Tile        Id  Gender
# 0   2014  December                    Dr. Carl Marci  44731082    male
# 0   2014  December                     Leelah Alcorn  44889641  female
# 0   2014  December                        Kogan Plan  44576988    male
# 0   2014  December                Nguyễn Công Phượng  45421322    male
# 0   2014  December                     Andrew Schwab  44971775    male
# 0   2014  December                 Milancy Khongstia  44871200    male
# 0   2014  December                       Brian Solis  17912166    male
# 0   2014  December                         Lele Pons  43774211  female
# 0   2014  December   Sennacherib's campaign in Judah     28334    male
# 0   2014  December             Charles Lucas Anthony  20752624    male
# 0   2014  December                   Jayme Amatnecks  44091983    male
# 0   2014  December             Noor Muhammad Maharvi  25276776    male
# 0   2014  December                     Kainat Soomro  33240805  female
# 0   2014  December                      Jim Sterling  43848209    male
# 0   2014  December                Fakhruddin Shaheed  35480473    male
# 0   2014  December          Home is Where the Bus Is  44651605    male
# 0   2014  December             Anne Beckwith Johnson  44771591  female
# 0   2014  December                     Júnior Lacayo  37331887    male
# 0   2014  December             John Ducas (investor)  43892409    male
# 0   2014  December                        Dave Comer  44859320    male
# 0   2014  December                     Luke Woodland  45676337    male
# 0   2014  December                    Carl A. Weeden   9699147    male
# 0   2014  December                  Alexis Railsback  44562107  female
# 0   2014  December                      Nick Cousins  45703737    male
# 0   2014  December                   Ranya Mordanova  44349190  female
# 0   2014  December                Paul Marc Rousseau  41460435    male
# 0   2014  December                 Francesca Gonshaw   4137934  female
# 0   2014  December                        Asami Sato  44877701  female
# 0   2014  December                 Arthur Mamou-Mani  44148999    male
# 0   2014  December                     Katja Glieson  39827615  female
# ..   ...       ...                               ...       ...     ...
# 0   2014   January                     Jennifer Lyon  25884645  female
# 0   2014   January                   Brendan Perlini  43004120    male
# 0   2014   January                   Robert Sungenis   1778598    male
# 0   2014   January               Christopher Willits   2628646    male
# 0   2014   January                  Michelle Schmitt  41830596  female
# 0   2014   January                    Roach (rapper)  38175306    male
# 0   2014   January                    Victor Orsatti  32024165    male
# 0   2014   January                   Grimes Poznikov   3293944    male
# 0   2014   January                       Thao Nguyen  15143429  female
# 0   2014   January                      ARIA (novel)  17189091    male
# 0   2014   January  Bill Lishman's underground house   1588724    male
# 0   2014   January               Alex Reid (fighter)  25018507    male
# 0   2014   January                       Dhiego Lima  45566571    male
# 0   2014   January                      Nyles Lannon  10403183    male
# 0   2014   January           Nahru Lampkin Bongo Man  36984788    male
# 0   2014   January                      Tom Nussbaum  38057383    male
# 0   2014   January                     Stephen Kline  37710234    male
# 0   2014   January                      Sunday Omony  33729647  female
# 0   2014   January                     Steven Shafer  38997723    male
# 0   2014   January                    Simon Cheffins  19926026    male
# 0   2014   January                    Tony Wasserman  34989637    male
# 0   2014   January                     Charles Veley   6091923    male
# 0   2014   January                  Stanhope defense   1339815    male
# 0   2014   January                          DJ Roxxi  42317662  female
# 0   2014   January                    Gajendra Verma  41200351    male
# 0   2014   January                     Satan's Angel  22468416  female
# 0   2014   January                       Guy Newland  24018920    male
# 0   2014   January                          Pink Man   7039818    male
# 0   2014   January     Laurent Schwartz (oncologist)  30029161    male
# 0   2014   January            Deborah Perry Piscione  36495092  female
#
# [3231 rows x 5 columns]

# %%
export_csv = df.to_csv (r'C:\Users\neiral\WS_semester2\CSS\nominatedForDeletion\2014.csv', index = None, header=True)

# %%
df2 = pd.read_csv('2014.csv')

# %%
print(len(df2))
print(len(df))
# Out:
# 3231
# 3231

# %%
pageLink = "/wiki/Patriotic_Nigras"
url = "http://dbpedia.org/page/"+pageLink.split("/wiki/")[1]
try :
    dbpediaPage = requests.get(url)
except requests.exceptions.RequestException as e:
    print(e)
soup = BeautifulSoup(dbpediaPage.content, "html.parser")
wikiIdTag = soup.find("span", {"property":"dbo:wikiPageID"})
genderTag = soup.find("span", {"property":"foaf:gender"})
print("Gender attr:",genderTag)
print("WikiId attr:",wikiIdTag)
if genderTag == None:
    print("Not a person")
# Out:
# Gender attr: None
# WikiId attr: <span property="dbo:wikiPageID" xmlns:dbo="http://dbpedia.org/ontology/">18799258</span>
# Not a person

# %%
print(url)
print("http://dbpedia.org/page/Carl_Marci")
# Out:
# http://dbpedia.org/page/Carl_Marci
# http://dbpedia.org/page/Carl_Marci

# %%
pageLink = "/wiki/Carl_Marci"
pageLink.split("/wiki/")[1]
# Out:
# 'Carl_Marci'

# %%
number = 27.58
number_int = number % 100
number_dec = number % 1

# %%
number_dec = round((number % 1 * 10), 2)
if int(number_dec) != number_dec:
    number_dec *= 10
    
print(int(number) + number_dec)
print(number_dec)
# Out:
# 85.0
# 58.0

# %%
number
# Out:
# 27.8
